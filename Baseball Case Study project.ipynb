# %% [markdown]
# # BASEBALL CASE STUDY PROJECT

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier,export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_recall_curve,roc_curve
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import cross_val_score
import joblib
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Examining The Data

# %%
df = pd.read_csv('Baseball Case study.csv')
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# This method print the information about the DataFrame including the index type and column type,non-null values and memory usage.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Dataset contains all sum values will be zero

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Here Dataset contains 30 rows and 17 columns

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# Here Dataset contains 17 columns

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# 1 The mean is more than median 50% percentile in all columns.
#
# 2 There is a large difference in 75% percentile and max .
#
# 3 The 1 and 2 observation suggest that there are extreme outliers present in these three columns.

# %%
df.ERA.unique()
# Out:
# array([3.73, 4.07, 3.67, 3.98, 4.64, 3.8 , 4.03, 4.05, 3.74, 4.31, 4.24,
#        3.57, 3.94, 4.16, 4.14, 2.94, 3.21, 3.36, 4.28, 4.33, 3.43, 3.62,
#        4.02, 4.41, 4.69, 3.44, 3.72, 4.04, 4.09, 5.04])

# %% [markdown]
# Target/dependent variables is discrete and categorial in nature

# %%
df.ERA.value_counts()
# Out:
# 3.57    1
# 3.72    1
# 4.03    1
# 4.69    1
# 4.31    1
# 3.67    1
# 3.94    1
# 3.62    1
# 4.14    1
# 4.16    1
# 3.98    1
# 4.04    1
# 4.28    1
# 3.80    1
# 4.24    1
# 4.09    1
# 3.44    1
# 4.07    1
# 3.43    1
# 4.64    1
# 3.21    1
# 5.04    1
# 4.33    1
# 4.02    1
# 4.05    1
# 2.94    1
# 3.73    1
# 3.74    1
# 4.41    1
# 3.36    1
# Name: ERA, dtype: int64

# %% [markdown]
# Here Dataset ERA contains categorical values

# %% [markdown]
# # Data Visualization

# %%
sns.countplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='count'>

# %% [markdown]
# Here Data is not normally distributed in the columns

# %%
sns.countplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='count'>

# %% [markdown]
# Here data is not normally distributed in these columns

# %%
sns.countplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='count'>

# %% [markdown]
# Here Data is not normally distributed in these columns

# %%
sns.countplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='count'>

# %% [markdown]
# Here Data is not normally distributed in these columns

# %%
sns.countplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='count'>

# %% [markdown]
# Here Data is not normally distributed in these columns

# %%
sns.countplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='count'>

# %% [markdown]
# Here Data is not normally distributed in these columns

# %%
sns.countplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='count'>

# %% [markdown]
# Here Data is not normally distributed in these columns

# %%
sns.countplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='count'>

# %% [markdown]
# Here Data is not normally distributed in these columns

# %%
sns.countplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='count'>

# %% [markdown]
# Here Data is  normally distributed in these columns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here heatmap contains all the nullvalues of the dataset.

# %%
dfcor=df.corr()
dfcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here heatmap containes the difference of corresponding values of dataset.
#
# Light shades are higly corrolated

# %%
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  Dark shades are higly correlated

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='Oranges',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Light shades are higly correlated
#
# E is higly correlated with SV
#
# SV is highly negatively correlated with ERA
#
# ERA is higly positively correlated with SO
#
# SO is higly positively correlated with 3B
#
# 3B is higly positively correlated with 2B
#
# AB is negatively correlated with E

# %% [markdown]
# # Plotting Outliers

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df['W'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here W have no outside the viscous so we cant find here outliers easily.

# %%
df['R'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here R have  outside the viscous so we can find here outliers easily.

# %%
df['AB'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here AB have no outside the viscous so we cant find here outliers easily.

# %%
df['H'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here H have no outside the viscous so we cant find here outliers easily.

# %%
df['2B'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here 2B have no outside the viscous so we cant find here outliers easily.

# %%
df['ERA'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here ERA have  outside the viscous so we can find here outliers easily.

# %%
df['SV'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here SV have  outside the viscous so we can find here outliers easily.

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Dataset contains 30 rows and 17 columns

# %%
collist=df.columns.values
ncol=17
nrows=10

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# Here we can find the collist of the all qualities and outliers.

# %% [markdown]
# # To Check  Distribution Skewness

# %%
sns.displot(df['W'])

# %% [markdown]
# Data is  not normally distributed in this columns.

# %%
sns.displot(df['R'])

# %% [markdown]
# Data is not  normally distributed in this columns.

# %%
sns.displot(df['AB'])

# %% [markdown]
# Data is not normally distributed in this columns.

# %%
sns.displot(df['H'])

# %% [markdown]
# Data is not normally distributed in this columns.

# %%
sns.displot(df['2B'])

# %% [markdown]
# Data is not normally distributed in this columns.

# %%
#plt.figure(figsize=(5*totalcol.5*totalcol))
plt.figure(figsize=(16,16))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.displot(df[collist[i]])
    plt.tight_layout()

# %% [markdown]
# other independent variables are right skewed/positively skewed

# %%
plt.scatter(df['W'],df['ERA'])

# %% [markdown]
# Here scatter the value of w and era

# %%
sns.pairplot(df)

# %% [markdown]
# Remove the missing values.
#
# drop  the nahativitycorrelated columns.
#
# remove the outliers.

# %%
plt.scatter(df['R'],df['ERA'])
plt.show()

# %% [markdown]
# Here scattring plot of R and ERA

# %%
df.drop('R',axis=1,inplace=True)

# %%
df.head()
# Out:
#     W    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  95  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  83  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  81  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  76  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  74  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
df.shape
# Out:
# (30, 16)

# %% [markdown]
# Dataset contains 30 rows and 16 columns

# %% [markdown]
# # Encoding Method

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["ERA"]=LE.fit_transform(df["ERA"])

# %%
df['ERA'].unique()
# Out:
# array([ 9, 18,  7, 13, 27, 11, 15, 17, 10, 24, 22,  5, 12, 21, 20,  0,  1,
#         2, 23, 25,  3,  6, 14, 26, 28,  4,  8, 16, 19, 29], dtype=int64)

# %%
df.head()
# Out:
#     W    AB     H   2B  3B   HR   BB    SO   SB   RA   ER  ERA  CG  SHO  SV  \
# 0  95  5575  1497  300  42  139  383   973  104  641  601    9   2    8  56
# 1  83  5467  1349  277  44  156  439  1264   70  700  653   18   2   12  45
# 2  81  5439  1395  303  29  141  533  1157   86  640  584    7  11   10  38
# 3  76  5533  1381  260  27  136  404  1231   68  701  643   13   7    9  37
# 4  74  5605  1515  289  49  151  455  1259   83  803  746   27   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
df.columns
# Out:
# Index(['W', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.3654086 , 0.84773126, 1.66368512, 1.42017307, 1.04119304,
#         0.7872986 , 1.53490242, 2.69762957, 0.91388329, 0.66623393,
#         0.50511008, 0.63543842, 0.5398062 , 0.81462859, 1.67160651,
#         0.46146963],
#        [0.1978383 , 0.71109353, 0.97068076, 0.12740339, 1.23580856,
#         0.24396668, 0.5365919 , 0.15487844, 0.60182558, 0.16597077,
#         0.24892985, 0.4043699 , 0.5398062 , 0.1728    , 0.24987932,
#         0.60719689],
#        [0.00324325, 1.1152333 , 0.15189137, 1.58879521, 0.22380785,
#         0.7233772 , 1.13914361, 0.89398189, 0.11144918, 0.68033909,
#         0.75162313, 0.86650693, 2.77264091, 0.32091429, 0.65485616,
#         1.11724227],
#        [0.48324437, 0.24152162, 0.40108814, 0.82812203, 0.41842337,
#         0.8831807 , 1.16053598, 0.16860185, 0.69098493, 0.18007593,
# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# thershold is 3 and print np where z>3

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       W    AB     H   2B  3B   HR   BB    SO   SB   RA   ER  ERA  CG  SHO  SV  \
# 0    95  5575  1497  300  42  139  383   973  104  641  601    9   2    8  56
# 1    83  5467  1349  277  44  156  439  1264   70  700  653   18   2   12  45
# 2    81  5439  1395  303  29  141  533  1157   86  640  584    7  11   10  38
# 3    76  5533  1381  260  27  136  404  1231   68  701  643   13   7    9  37
# 4    74  5605  1515  289  49  151  455  1259   83  803  746   27   7   12  35
# 5    93  5509  1480  308  17  232  570  1151   88  670  609   11   7   10  34
# 6    87  5567  1397  272  19  212  554  1227   63  698  652   15   3    4  48
# 7    81  5485  1370  246  20  217  418  1331   44  693  646   17   0   10  43
# 8    80  5485  1383  278  32  167  436  1310   87  642  604   10   1   12  60
# 9    78  5640  1495  294  33  161  478  1148   71  753  694   24   3   10  40
# 10   88  5511  1419  279  32  172  503  1233  101  733  680   22   5    9  45
# 11   86  5459  1363  278  26  230  486  1392  121  618  572    5   5   13  39
# 12   85  5417  1331  243  21  176  435  1150   52  675  630   12   2   12  46
# 13   76  5544  1379  262  22  198  478  1336   69  726  677   21   6   12  45
# 14   68  5600  1405  277  46  146  475  1119   78  729  664   20   5   15  28
# 15  100  5484  1386  288  39  137  506  1267   69  525  478    0   1   15  62
# 16   98  5631  1462  292  27  140  461  1322   98  596  532    1   0   13  54
# 17   97  5491  1341  272  30  171  567  1518   95  608  546    2   6   21  48
# 18   68  5480  1378  274  34  145  412  1299   84  737  682   23   1    7  40
# 19   64  5571  1382  257  27  167  496  1255  134  754  700   25   2    8  35
# 20   90  5527  1351  295  17  177  488  1290   51  613  557    3   1   14  50
# 21   83  5428  1363  265  13  177  539  1344   57  635  577    6   4   13  41
# 22   71  5463  1420  236  40  120  375  1150  112  678  638   14   0   12  35
# 23   67  5420  1361  251  18  100  471  1107   69  760  698   26   3   10  44
# 24   63  5529  1374  272  37  130  387  1274   88  809  749   28   1    7  35
# 25   92  5385  1346  263  26  187  563  1258   59  595  553    4   6   21  47
# 26   84  5565  1486  288  39  136  457  1159   93  627  597    8   7   18  41
# 27   79  5649  1494  289  48  154  490  1312  132  713  659   16   1   12  44
# 28   74  5457  1324  260  36  148  426  1327   82  731  655   19   1    6  41
# 29   68  5572  1479  274  49  186  388  1283   97  844  799   29   4    4  36
#
#       E
# 0    88
# 1    86
# 2    79
# 3   101
# 4    86
# 5    88
# 6    93
# 7    77
# 8    95
# 9    97
# 10  119
# 11   85
# 12   93
# 13   94
# 14  126
# 15   96
# 16  122
# 17  111
# 18  116
# 19   90
# 20   88
# 21   90
# 22   77
# 23   90
# 24  117
# 25   75
# 26   78
# 27   86
# 28   92
# 29   95

# %%
df.shape
# Out:
# (30, 16)

# %% [markdown]
# Dataset contains 30 rows and 16 columns

# %%
df_new.shape
# Out:
# (30, 16)

# %% [markdown]
# Dataset contains new shapes 30 rows and 16 columns

# %% [markdown]
# # StandardScaler Method

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
sc
#         -1.39455191, -1.67751821, -0.96259892,  1.27052067, -0.14434285,
#          0.03141833, -0.05776713, -1.27590555,  0.1728    , -1.04259994,
#         -1.26296953],
#        [-1.3589221 , -1.38947099, -0.75708353, -1.33398843, -1.29419322,
#         -2.03376593,  0.03387125, -1.38410355, -0.64640525,  1.01228062,
#          0.9014644 ,  1.32864396, -0.17175652, -0.32091429,  0.1206314 ,
#         -0.31574238],
#        [-1.74811219,  0.18378737, -0.52568653, -0.1536335 ,  0.55465424,
#         -1.07494491, -1.46359453,  0.25290277,  0.20060853,  1.70343367,
#          1.64100356,  1.55971247, -0.90785587, -1.06148574, -1.04259994,
#          1.65157553],
#        [ 1.07351602, -1.8946457 , -1.02408007, -0.6594999 , -0.51573113,
#          0.74681504,  1.67395282,  0.09606384, -1.09220198, -1.31507148,
#         -1.20114693, -1.2131097 ,  0.93239252,  2.39451435,  0.50837518,
#         -1.40869678],
#        [ 0.29513583,  0.70339563,  1.46788766,  0.74568454,  0.74926976,
#         -0.8831807 , -0.21570638, -0.87437703,  0.42350689, -0.86370623,
#         -0.56311315, -0.75097267,  1.3004422 ,  1.6539429 , -0.26711238,
#         -1.1901059 ],
#        [-0.1913518 ,  1.91581492,  1.61028582,  0.80189192,  1.6250396 ,
#         -0.30788808,  0.37258375,  0.62539523,  2.16211413,  0.3493379 ,
#          0.33593445,  0.17330139, -0.90785587,  0.1728    ,  0.1206314 ,
#         -0.60719689],
#        [-0.67783942, -0.85542916, -1.415675  , -0.82812203,  0.45734648,
#         -0.49965229, -0.76834256,  0.77243172, -0.06686951,  0.60323086,
#          0.27793138,  0.51990416, -0.90785587, -1.30834289, -0.26711238,
#         -0.17001513],
#        [-1.26162457,  0.80443057,  1.34328927, -0.04121874,  1.72234737,
#          0.71485434, -1.44576756,  0.34112467,  0.60182558,  2.19711442,
#          2.36604195,  1.67524673,  0.19629316, -1.80205719, -0.91335201,
#          0.04857575]])

# %%
from sklearn.decomposition import PCA

testpca = PCA()
Y = testpca.fit(scaledX)

# %%
Y.explained_variance_ratio_
# Out:
# array([3.35866653e-01, 1.71593290e-01, 1.18084459e-01, 8.66155656e-02,
#        7.47912370e-02, 6.13344179e-02, 3.90198449e-02, 3.01591480e-02,
#        2.44360610e-02, 1.87222235e-02, 1.60542590e-02, 9.32179933e-03,
#        8.42757958e-03, 4.03760244e-03, 1.37271889e-03, 1.63140790e-04])

# %%
var_cumu = np.cumsum(Y.explained_variance_ratio_)*100
var_cumu
# Out:
# array([ 33.58666529,  50.74599428,  62.55444021,  71.21599678,
#         78.69512047,  84.82856226,  88.73054675,  91.74646155,
#         94.19006764,  96.06228999,  97.6677159 ,  98.59989583,
#         99.44265379,  99.84641403,  99.98368592, 100.        ])

# %%
k = np.argmax(var_cumu>99)
print("Number of components explaining 99% variance:",k)
# Out:
# Number of components explaining 99% variance: 12

# %%
plt.ylabel('Cumulative Expalined varience')
plt.xlabel('Principle components')
plt.axvline(x=k, color="k",linestyle="--")
plt.axhline(y=9, color="r",linestyle="--")

plt.plot(var_cumu)
plt.show()

# %% [markdown]
# # checking skewness

# %%
df.skew()
# Out:
# W      0.047089
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.000000
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # Regressor Methods

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

# %%
x = df.drop(['ERA'],axis=1)
y = df["ERA"]
x_train, x_test, y_train, y_test=train_test_split(x, y, random_state=0, test_size=0.2)

# %%
from sklearn.metrics import mean_squared_error
for i in range(200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=i)
    from sklearn.tree import DecisionTreeRegressor
    lm=DecisionTreeRegressor()
    lm.fit(x_train,y_train)
    y_pred=lm.predict(x_test)
    mse=mean_squared_error(y_test,y_pred)
    rmse = np.sqrt(mse)
    print(rmse)
# Out:
# 3.331666249791536
# 3.7682887362833544
# 5.385164807134504
# 2.6076809620810595
# 4.03732584763727
# 2.3874672772626644
# 2.792848008753788
# 2.6457513110645907
# 3.492849839314596
# 5.224940191045253
# 4.449719092257398
# 3.361547262794322
# 4.358898943540674
# 3.5355339059327378
# 5.385164807134504
# 3.521363372331802
# 4.701063709417263
# 3.1304951684997055
# 3.3763886032268267
# 4.159326868617084
# 5.744562646538029
# 3.847076812334269
# 3.146426544510455
# 2.792848008753788
# 1.8708286933869707
# 3.7549966711037173
# 4.266145801540309
# 2.5495097567963922
# 2.6645825188948455
# 3.03315017762062
# 2.1447610589527217
# 3.0
# 2.8106938645110393
# 3.1780497164141406
# 2.280350850198276
# 2.073644135332772
# 4.266145801540309
# 4.764451699828638
# 3.146426544510455
# 4.494441010848846
# 3.1144823004794873
# 2.792848008753788
# 2.932575659723036
# 2.5298221281347035
# 3.0659419433511785
# 2.6832815729997477
# 2.8460498941515415
# 3.96232255123179
# 3.5496478698597698
# 3.391164991562634
# 2.1447610589527217
# 4.2895221179054435
# 5.504543577809154
# 2.5495097567963922
# 3.0495901363953815
# 4.024922359499621
# 3.0495901363953815
# 4.795831523312719
# 3.4641016151377544
# 3.5496478698597698
# 3.8987177379235853
# 6.115553940568262
# 2.7748873851023217
# 2.6457513110645907
# 2.9832867780352594
# 3.271085446759225
# 2.449489742783178
# 2.898275349237888
# 2.4698178070456938
# 4.857983120596447
# 2.8460498941515415
# 3.271085446759225
# 3.7549966711037173
# 2.5495097567963922
# 2.8635642126552705
# 4.1952353926806065
# 3.794733192202055
# 3.9496835316262997
# 2.2135943621178655
# 3.5355339059327378
# 7.224956747275377
# 2.7386127875258306
# 2.932575659723036
# 2.6267851073127395
# 4.370354676682432
# 3.082207001484488
# 2.32379000772445
# 2.3874672772626644
# 2.04939015319192
# 2.8284271247461903
# 2.9832867780352594
# 2.7202941017470885
# 4.43846820423443
# 3.146426544510455
# 3.391164991562634
# 2.16794833886788
# 2.588435821108957
# 2.9664793948382653
# 4.09878030638384
# 6.340346993658944
# 1.816590212458495
# 3.8987177379235853
# 3.255764119219941
# 3.794733192202055
# 2.588435821108957
# 5.805170109479997
# 3.5496478698597698
# 3.7013511046643495
# 2.04939015319192
# 2.345207879911715
# 4.483302354291979
# 2.569046515733026
# 3.5777087639996634
# 3.2093613071762426
# 2.1447610589527217
# 2.7202941017470885
# 3.8858718455450894
# 3.687817782917155
# 3.605551275463989
# 4.024922359499621
# 2.4083189157584592
# 2.9832867780352594
# 2.2135943621178655
# 2.8284271247461903
# 4.207136793592526
# 1.4832396974191326
# 3.9749213828703582
# 2.932575659723036
# 1.9493588689617927
# 2.898275349237888
# 2.4698178070456938
# 3.361547262794322
# 2.8284271247461903
# 3.1937438845342623
# 3.22490309931942
# 2.7386127875258306
# 3.0983866769659336
# 2.588435821108957
# 4.505552130427524
# 3.605551275463989
# 3.1937438845342623
# 4.929503017546495
# 2.7386127875258306
# 3.1937438845342623
# 2.6645825188948455
# 3.391164991562634
# 2.04939015319192
# 2.8635642126552705
# 2.588435821108957
# 3.082207001484488
# 2.792848008753788
# 2.0248456731316584
# 4.0
# 5.300943312279429
# 2.5495097567963922
# 2.6457513110645907
# 4.494441010848846
# 2.949576240750525
# 3.2093613071762426
# 4.857983120596447
# 3.391164991562634
# 2.23606797749979
# 5.263078946776307
# 1.8708286933869707
# 3.2093613071762426
# 4.415880433163924
# 2.6645825188948455
# 2.32379000772445
# 3.082207001484488
# 3.255764119219941
# 3.63318042491699
# 2.6832815729997477
# 3.8600518131237567
# 2.2135943621178655
# 5.196152422706632
# 1.816590212458495
# 3.5071355833500366
# 2.949576240750525
# 4.06201920231798
# 2.8284271247461903
# 3.22490309931942
# 3.391164991562634
# 2.7386127875258306
# 3.478505426185217
# 5.0099900199501395
# 3.9749213828703582
# 3.8600518131237567
# 5.813776741499453
# 3.6742346141747673
# 3.7682887362833544
# 2.9154759474226504
# 4.679743582719036
# 4.183300132670378
# 3.9496835316262997
# 4.878524367060187
# 3.2093613071762426
# 2.6076809620810595
# 4.415880433163924
# 2.701851217221259
# 2.8809720581775866

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([ 4., 15., 19., 26.,  3., 23., 26.,  7.,  3., 15.])

# %%
dt_accuracy = round(regressor.score(x_train,y_train)*100,2)
dt_accuracy
# Out:
# 100.0

# %% [markdown]
# The Test Accuracy of DecisionTreeRegressor is 100

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([ 5.49, 12.47, 18.79, 24.34,  5.85, 21.64, 24.46,  8.2 ,  5.89,
#        16.22])

# %%
rf_accuracy = round(regressor.score(x_train,y_train)*100,2)
rf_accuracy
# Out:
# 98.74

# %% [markdown]
# The Test Accuracy of RandomForestRegressor is 98.74

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([ 3.67617371, 16.04719414, 15.68921012, 22.39673799, -5.17612376,
#        25.16140658, 23.51263819,  4.36017877,  2.45661316, 13.95971741])

# %%
lr_accuracy = round(regressor.score(x_train,y_train)*100,2)
lr_accuracy
# Out:
# 97.87

# %% [markdown]
# The Test Accuracy of LogisticRegression is 97.87

# %%
from sklearn.naive_bayes import GaussianNB
regressor = GaussianNB()
regressor.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([ 5, 14, 27, 27,  3, 22, 22, 11,  3, 19], dtype=int64)

# %%
nb_accuracy = round(regressor.score(x_train,y_train)*100,2)
nb_accuracy
# Out:
# 100.0

# %% [markdown]
# The Test Accuracy of nb is 100

# %%
from sklearn.svm import SVR
regressor = SVR()
regressor.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([14.49307765, 14.49468812, 14.50967482, 14.51076674, 14.47469684,
#        14.50506593, 14.51230266, 14.49184232, 14.49120228, 14.50299318])

# %%
svm_accuracy = round(regressor.score(x_train,y_train)*100,2)
svm_accuracy
# Out:
# -1.02

# %% [markdown]
# The Test Accuracy of SVR is -1.02

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor()
regressor.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([ 9. , 14. , 19.6, 17.6,  6. , 18. , 18.8, 13.4,  9.2, 16.4])

# %%
knn_accuracy = round(regressor.score(x_train,y_train)*100,2)
knn_accuracy
# Out:
# 83.41

# %% [markdown]
# The Test Accuracy of KNN is 83.14

# %% [markdown]
# # Cross value correction

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
print(cross_val_score(regressor,x,y,cv=5).mean())
# Out:
# 0.837261961259513

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()
print(cross_val_score(regressor,x,y,cv=5).mean())
# Out:
# 0.9085801221268077

# %%
from sklearn.svm import SVR
regressor = SVR()
print(cross_val_score(regressor,x,y,cv=5).mean())
# Out:
# -0.16606933270942772

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
print(cross_val_score(regressor,x,y,cv=5).mean())
# Out:
# 0.7275049144503335

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor()
print(cross_val_score(regressor,x,y,cv=5).mean())
# Out:
# 0.6243694422407451

# %% [markdown]
# # Hyperparameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {"max_depth":[1,3,5,7,9,11,12],
             'criterion':['mse','friedman_mse']}

# %%
GCV = GridSearchCV(DecisionTreeRegressor(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['mse', 'friedman_mse'],
#                          'max_depth': [1, 3, 5, 7, 9, 11, 12]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'mse', 'max_depth': 12}

# %% [markdown]
# # Evaluate The Model

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
regressor.fit(x_train,y_train)
Final_mod = DecisionTreeRegressor()
Final_mod.fit(x_train,y_train)
pred = Final_mod.predict(x_test)
print((regressor.score(x_test,y_test)*100))
# Out:
# 78.54662698412697

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(Final_mod,"FinalModle.pkl")
# Out:
# ['FinalModle.pkl']

# %% [markdown]
# Here saving the model finalmodle.pkl

# %% [markdown]
# # Prediction Method

# %%
Final_mod = DecisionTreeRegressor()
Final_mod.fit(x_train,y_train)
pred = Final_mod.predict(x_test)
preds = regressor.predict(x_test)
print(preds[:36])
print(y_test[:36].values)
# Out:
# [ 4. 17. 10. 27.  4. 19. 26.  7.  5. 10.]
# [ 2 12 16 24  0 20 25  8  1 18]

# %% [markdown]
# The train and test data is balanced most classification methods hit the 81% accuracy with the datset.
